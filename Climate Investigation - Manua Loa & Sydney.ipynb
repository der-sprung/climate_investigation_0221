# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exploring Sydney Data

# %% [markdown]
# Taking data readings from a Sydney weather station, we will do some exploration & cleaning to better understand the data.

# %%
# Reading in CSV file into a DF
sydney = pd.read_csv('IDCJAC0010_066062_1800_Data.csv')
sydney
# Out:
#       Product code  Bureau of Meteorology station number  Year  Month  Day  \
# 0       IDCJAC0010                                 66062  1859      1    1
# 1       IDCJAC0010                                 66062  1859      1    2
# 2       IDCJAC0010                                 66062  1859      1    3
# 3       IDCJAC0010                                 66062  1859      1    4
# 4       IDCJAC0010                                 66062  1859      1    5
# ...            ...                                   ...   ...    ...  ...
# 59042   IDCJAC0010                                 66062  2020      8   26
# 59043   IDCJAC0010                                 66062  2020      8   27
# 59044   IDCJAC0010                                 66062  2020      8   28
# 59045   IDCJAC0010                                 66062  2020      8   29
# 59046   IDCJAC0010                                 66062  2020      8   30
#
#        Maximum temperature (Degree C)  \
# 0                                24.4
# 1                                24.4
# 2                                24.2
# 3                                24.7
# 4                                24.6
# ...                               ...
# 59042                            19.6
# 59043                            22.2
# 59044                            19.7
# 59045                            21.5
# 59046                            25.3
#
#        Days of accumulation of maximum temperature Quality
# 0                                              NaN       Y
# 1                                              1.0       Y
# 2                                              1.0       Y
# 3                                              1.0       Y
# 4                                              1.0       Y
# ...                                            ...     ...
# 59042                                          1.0       Y
# 59043                                          1.0       Y
# 59044                                          1.0       Y
# 59045                                          1.0       Y
# 59046                                          1.0       Y
#
# [59047 rows x 8 columns]

# %% [markdown]
# Initial exploration of the sydney DF

# %%
sydney.nunique()
# Out:
# Product code                                     1
# Bureau of Meteorology station number             1
# Year                                           162
# Month                                           12
# Day                                             31
# Maximum temperature (Degree C)                 334
# Days of accumulation of maximum temperature      2
# Quality                                          1
# dtype: int64

# %%
sydney.isnull().sum()
# Out:
# Product code                                     0
# Bureau of Meteorology station number             0
# Year                                             0
# Month                                            0
# Day                                              0
# Maximum temperature (Degree C)                 152
# Days of accumulation of maximum temperature    285
# Quality                                        153
# dtype: int64

# %%
# cleaning up the column names
sydney.columns = ['prod_id','station_id','year','month',
                'day','max_temp','days_accumulated','quality']
sydney
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 0      IDCJAC0010       66062  1859      1    1      24.4               NaN
# 1      IDCJAC0010       66062  1859      1    2      24.4               1.0
# 2      IDCJAC0010       66062  1859      1    3      24.2               1.0
# 3      IDCJAC0010       66062  1859      1    4      24.7               1.0
# 4      IDCJAC0010       66062  1859      1    5      24.6               1.0
# ...           ...         ...   ...    ...  ...       ...               ...
# 59042  IDCJAC0010       66062  2020      8   26      19.6               1.0
# 59043  IDCJAC0010       66062  2020      8   27      22.2               1.0
# 59044  IDCJAC0010       66062  2020      8   28      19.7               1.0
# 59045  IDCJAC0010       66062  2020      8   29      21.5               1.0
# 59046  IDCJAC0010       66062  2020      8   30      25.3               1.0
#
#       quality
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           Y
# ...       ...
# 59042       Y
# 59043       Y
# 59044       Y
# 59045       Y
# 59046       Y
#
# [59047 rows x 8 columns]

# %%
# looking to understand if days_accumulated is a negligible column
sydney['days_accumulated'].value_counts()
# Out:
# 1.0    58761
# 2.0        1
# Name: days_accumulated, dtype: int64

# %%
sydney[sydney['days_accumulated']==2.0]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 50219  IDCJAC0010       66062  1996      6   30      18.4               2.0
#
#       quality
# 50219       Y

# %%
# looking to understand if quality is a negligible column
sydney['quality'].value_counts()
# Out:
# Y    58894
# Name: quality, dtype: int64

# %% [markdown]
# The column 'quality' relates to whether the station could read in data reliably for the day. For NaN values the max_temp isn't reliable.

# %%
sydney[sydney['quality'] != 'Y']
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 720    IDCJAC0010       66062  1860     12   21       NaN               NaN
# 1905   IDCJAC0010       66062  1864      3   20       NaN               NaN
# 2367   IDCJAC0010       66062  1865      6   25       NaN               1.0
# 3330   IDCJAC0010       66062  1868      2   13       NaN               NaN
# 3748   IDCJAC0010       66062  1869      4    6       NaN               NaN
# ...           ...         ...   ...    ...  ...       ...               ...
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
# 50336  IDCJAC0010       66062  1996     10   25       NaN               NaN
# 55143  IDCJAC0010       66062  2009     12   23       NaN               NaN
# 55144  IDCJAC0010       66062  2009     12   24       NaN               NaN
# 56944  IDCJAC0010       66062  2014     11   28      23.3               1.0
#
#       quality
# 720       NaN
# 1905      NaN
# 2367      NaN
# 3330      NaN
# 3748      NaN
# ...       ...
# 50335     NaN
# 50336     NaN
# 55143     NaN
# 55144     NaN
# 56944     NaN
#
# [153 rows x 8 columns]

# %% [markdown]
# The 'days_accumalated' column also contains a lot of Nan values.

# %%
sydney[sydney['days_accumulated'].isnull()]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 0      IDCJAC0010       66062  1859      1    1      24.4               NaN
# 720    IDCJAC0010       66062  1860     12   21       NaN               NaN
# 721    IDCJAC0010       66062  1860     12   22      20.9               NaN
# 1905   IDCJAC0010       66062  1864      3   20       NaN               NaN
# 1906   IDCJAC0010       66062  1864      3   21      19.6               NaN
# ...           ...         ...   ...    ...  ...       ...               ...
# 50334  IDCJAC0010       66062  1996     10   23       NaN               NaN
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
# 50336  IDCJAC0010       66062  1996     10   25       NaN               NaN
# 55143  IDCJAC0010       66062  2009     12   23       NaN               NaN
# 55144  IDCJAC0010       66062  2009     12   24       NaN               NaN
#
#       quality
# 0           Y
# 720       NaN
# 721         Y
# 1905      NaN
# 1906        Y
# ...       ...
# 50334     NaN
# 50335     NaN
# 50336     NaN
# 55143     NaN
# 55144     NaN
#
# [285 rows x 8 columns]

# %%
sydney.dtypes
# Out:
# prod_id              object
# station_id            int64
# year                  int64
# month                 int64
# day                   int64
# max_temp            float64
# days_accumulated    float64
# quality              object
# dtype: object

# %%
sydney.shape
# Out:
# (59047, 8)

# %% [markdown]
# ### Dealing with Nulls

# %% [markdown]
# Looking for instances where all recorded data (max_temp, days_accumulated, quality) are null. Searched for alternate datasets to impute values, however no sources are of a close enough relevance to impute without compromising integrity. It is better to remove values, or impute with mean.

# %%
# searching for null values in quality & max_temp & days_accumulated as these days had data recording issues
sydney[(sydney['quality'].isnull()) & (sydney['max_temp'].isnull()) & (sydney['days_accumulated'].isnull())]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 720    IDCJAC0010       66062  1860     12   21       NaN               NaN
# 1905   IDCJAC0010       66062  1864      3   20       NaN               NaN
# 3330   IDCJAC0010       66062  1868      2   13       NaN               NaN
# 3748   IDCJAC0010       66062  1869      4    6       NaN               NaN
# 4074   IDCJAC0010       66062  1870      2   26       NaN               NaN
# ...           ...         ...   ...    ...  ...       ...               ...
# 50334  IDCJAC0010       66062  1996     10   23       NaN               NaN
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
# 50336  IDCJAC0010       66062  1996     10   25       NaN               NaN
# 55143  IDCJAC0010       66062  2009     12   23       NaN               NaN
# 55144  IDCJAC0010       66062  2009     12   24       NaN               NaN
#
#       quality
# 720       NaN
# 1905      NaN
# 3330      NaN
# 3748      NaN
# 4074      NaN
# ...       ...
# 50334     NaN
# 50335     NaN
# 50336     NaN
# 55143     NaN
# 55144     NaN
#
# [150 rows x 8 columns]

# %%
# Adding new column, rolling average. Calculated off a 3 day window, using the day before and the day after 
#(to help impute missing values based on weather the day before & after)
sydney['rolling_avg'] = round(sydney['max_temp'].rolling(3, min_periods=1, center=True).mean(), 1)

# %%
# Find remaining instances of nulls due to too much missing data for a window of 2 days
sydney[sydney['rolling_avg'].isnull() == True]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 50334  IDCJAC0010       66062  1996     10   23       NaN               NaN
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
#
#       quality  rolling_avg
# 50334     NaN          NaN
# 50335     NaN          NaN

# %%
# checking distribution of rolling_avg is similar to max_temp, and hence can be used as an accurate placeholder
sydney[(sydney['year'] == 1996) & (sydney['month'] == 10) & (sydney['day'] > 15)]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 50327  IDCJAC0010       66062  1996     10   16      24.9               1.0
# 50328  IDCJAC0010       66062  1996     10   17       NaN               NaN
# 50329  IDCJAC0010       66062  1996     10   18      23.1               1.0
# 50330  IDCJAC0010       66062  1996     10   19      27.1               1.0
# 50331  IDCJAC0010       66062  1996     10   20      16.5               1.0
# 50332  IDCJAC0010       66062  1996     10   21      18.6               1.0
# 50333  IDCJAC0010       66062  1996     10   22       NaN               NaN
# 50334  IDCJAC0010       66062  1996     10   23       NaN               NaN
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
# 50336  IDCJAC0010       66062  1996     10   25       NaN               NaN
# 50337  IDCJAC0010       66062  1996     10   26      18.5               1.0
# 50338  IDCJAC0010       66062  1996     10   27      18.9               1.0
# 50339  IDCJAC0010       66062  1996     10   28      22.5               1.0
# 50340  IDCJAC0010       66062  1996     10   29      22.5               1.0
# 50341  IDCJAC0010       66062  1996     10   30      22.7               1.0
# 50342  IDCJAC0010       66062  1996     10   31      19.4               1.0
#
#       quality  rolling_avg
# 50327       Y         23.7
# 50328     NaN         24.0
# 50329       Y         25.1
# 50330       Y         22.2
# 50331       Y         20.7
# 50332       Y         17.5
# 50333     NaN         18.6
# 50334     NaN          NaN
# 50335     NaN          NaN
# 50336     NaN         18.5
# 50337       Y         18.7
# 50338       Y         20.0
# 50339       Y         21.3
# 50340       Y         22.6
# 50341       Y         21.5
# 50342       Y         20.9

# %%
#Remaining 2 NaNs are due to a large blip in recording. Use rolling average to impute these values.
sydney.loc[(sydney['rolling_avg'].isnull() == True), 'rolling_avg'] = \
round(sydney['rolling_avg'].rolling(3, min_periods=1, center=True).mean(), 1)

# %%
# checking output of rolling averages
sydney[(sydney['year'] == 1996) & (sydney['month'] == 10) & (sydney['day'] > 20)]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 50332  IDCJAC0010       66062  1996     10   21      18.6               1.0
# 50333  IDCJAC0010       66062  1996     10   22       NaN               NaN
# 50334  IDCJAC0010       66062  1996     10   23       NaN               NaN
# 50335  IDCJAC0010       66062  1996     10   24       NaN               NaN
# 50336  IDCJAC0010       66062  1996     10   25       NaN               NaN
# 50337  IDCJAC0010       66062  1996     10   26      18.5               1.0
# 50338  IDCJAC0010       66062  1996     10   27      18.9               1.0
# 50339  IDCJAC0010       66062  1996     10   28      22.5               1.0
# 50340  IDCJAC0010       66062  1996     10   29      22.5               1.0
# 50341  IDCJAC0010       66062  1996     10   30      22.7               1.0
# 50342  IDCJAC0010       66062  1996     10   31      19.4               1.0
#
#       quality  rolling_avg
# 50332       Y         17.5
# 50333     NaN         18.6
# 50334     NaN         18.6
# 50335     NaN         18.5
# 50336     NaN         18.5
# 50337       Y         18.7
# 50338       Y         20.0
# 50339       Y         21.3
# 50340       Y         22.6
# 50341       Y         21.5
# 50342       Y         20.9

# %%
# imputing rolling average values where max_temp is null
sydney.loc[(sydney['max_temp'].isnull() == True), 'max_temp'] = sydney['rolling_avg']

# %%
# Check values have been imputed
sydney[(sydney['year'] == 1996) & (sydney['month'] == 10) & (sydney['day'] > 20)]
# Out:
#           prod_id  station_id  year  month  day  max_temp  days_accumulated  \
# 50332  IDCJAC0010       66062  1996     10   21      18.6               1.0
# 50333  IDCJAC0010       66062  1996     10   22      18.6               NaN
# 50334  IDCJAC0010       66062  1996     10   23      18.6               NaN
# 50335  IDCJAC0010       66062  1996     10   24      18.5               NaN
# 50336  IDCJAC0010       66062  1996     10   25      18.5               NaN
# 50337  IDCJAC0010       66062  1996     10   26      18.5               1.0
# 50338  IDCJAC0010       66062  1996     10   27      18.9               1.0
# 50339  IDCJAC0010       66062  1996     10   28      22.5               1.0
# 50340  IDCJAC0010       66062  1996     10   29      22.5               1.0
# 50341  IDCJAC0010       66062  1996     10   30      22.7               1.0
# 50342  IDCJAC0010       66062  1996     10   31      19.4               1.0
#
#       quality  rolling_avg
# 50332       Y         17.5
# 50333     NaN         18.6
# 50334     NaN         18.6
# 50335     NaN         18.5
# 50336     NaN         18.5
# 50337       Y         18.7
# 50338       Y         20.0
# 50339       Y         21.3
# 50340       Y         22.6
# 50341       Y         21.5
# 50342       Y         20.9

# %% [markdown]
# ## Identify Seasonality

# %%
# The average maximum daily temperature since records began..
mean_temp = sydney['max_temp'].mean()
print(f"{round(sydney['max_temp'].mean(),4)} \N{DEGREE SIGN}C")
# Out:
# 21.7458 °C

# %%
# Drilling down, the average temperature by month.
month_temp = pd.DataFrame(sydney.groupby(by=sydney['month'])['max_temp'].mean())
month_temp['month_name'] = pd.Series(
    ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
     'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']).values
month_temp
# Out:
#         max_temp month_name
# month
# 1      26.010056        Jan
# 2      25.839598        Feb
# 3      24.809299        Mar
# 4      22.514856        Apr
# 5      19.531282        May
# 6      17.011008        Jun
# 7      16.422322        Jul
# 8      17.891794        Aug
# 9      20.084824        Sep
# 10     22.170246        Oct
# 11     23.686874        Nov
# 12     25.247526        Dec

# %% [markdown]
# Plotting it! The dotted line is the overall average temperature found initially

# %%
pal = sns.color_palette("Spectral", 12)
rank = month_temp['max_temp'].argsort().argsort()

g = sns.barplot(data=month_temp, x='month_name', 
                y='max_temp', palette = np.array(pal[::-1])[rank])
g.axhline(sydney['max_temp'].mean(), color='black', linestyle='--');

# %%
# Calculating the difference of the month's average tempratures from the overall average temprature
month_temp['temp_diff'] = month_temp['max_temp'] - mean_temp
month_temp
# Out:
#         max_temp month_name  temp_diff
# month
# 1      26.010056        Jan   4.264233
# 2      25.839598        Feb   4.093775
# 3      24.809299        Mar   3.063476
# 4      22.514856        Apr   0.769033
# 5      19.531282        May  -2.214540
# 6      17.011008        Jun  -4.734815
# 7      16.422322        Jul  -5.323501
# 8      17.891794        Aug  -3.854028
# 9      20.084824        Sep  -1.660999
# 10     22.170246        Oct   0.424424
# 11     23.686874        Nov   1.941051
# 12     25.247526        Dec   3.501703

# %% [markdown]
# ## Seasonality Correction

# %%
# Merging the monthly temperature DF onto the main daily temperature DF
syd_lookup = sydney.merge(month_temp, how='left', on='month', validate='m:1', suffixes=('_syd', '_mon'))

# %%
# Creating a column of adjusted temperatures from the merged DF
syd_lookup['max_temp_adj'] = syd_lookup['max_temp_syd'] - syd_lookup['temp_diff']
syd_lookup[['year','month','day','max_temp_mon','temp_diff','max_temp_adj']]
# Out:
#        year  month  day  max_temp_mon  temp_diff  max_temp_adj
# 0      1859      1    1     26.010056   4.264233     20.135767
# 1      1859      1    2     26.010056   4.264233     20.135767
# 2      1859      1    3     26.010056   4.264233     19.935767
# 3      1859      1    4     26.010056   4.264233     20.435767
# 4      1859      1    5     26.010056   4.264233     20.335767
# ...     ...    ...  ...           ...        ...           ...
# 59042  2020      8   26     17.891794  -3.854028     23.454028
# 59043  2020      8   27     17.891794  -3.854028     26.054028
# 59044  2020      8   28     17.891794  -3.854028     23.554028
# 59045  2020      8   29     17.891794  -3.854028     25.354028
# 59046  2020      8   30     17.891794  -3.854028     29.154028
#
# [59047 rows x 6 columns]

# %%
# Grouping the two temperature columns by year
temp_adj = syd_lookup.groupby(by='year', as_index=False)[['max_temp_adj', 'max_temp_syd']].mean()
temp_adj
# Out:
#      year  max_temp_adj  max_temp_syd
# 0    1859     21.400086     21.399452
# 1    1860     20.270868     20.281421
# 2    1861     20.865292     20.864658
# 3    1862     21.353785     21.353151
# 4    1863     20.959812     20.959178
# ..    ...           ...           ...
# 157  2016     23.829611     23.840164
# 158  2017     23.678442     23.677808
# 159  2018     23.363648     23.363014
# 160  2019     24.015429     24.014795
# 161  2020     23.088457     22.584774
#
# [162 rows x 3 columns]

# %%
# Finally plotting the change in temperature over time! 😓
sns.lmplot(data=temp_adj, x='year', y='max_temp_adj', logx=True);

# %% [markdown]
# # Dataset 2 - Manua Loa

# %% [markdown]
# ### Exploring Manua Loa

# %%
# Reading in Mauna Loa dataset
mauna = pd.read_csv('mauna_loa_co2_levels.csv')

# %%
# Renaming columns to suit convention
mauna.columns = ['year', 'month', 'co2_ppm']

# %%
# Checking for nulls
mauna.isnull().sum()
# Out:
# year       0
# month      0
# co2_ppm    0
# dtype: int64

# %%
# Checking for anomalies
mauna[mauna['co2_ppm'] < 0 ].head()
# Out:
#     year  month  co2_ppm
# 3   1958      6   -99.99
# 7   1958     10   -99.99
# 71  1964      2   -99.99
# 72  1964      3   -99.99
# 73  1964      4   -99.99

# %% [markdown]
# Instances where co2_ppm = -99.99 are null values. As these values span a large time frame, imputing a mean value for a month may skew the data for a calculation of that year. Leaving them in will will also skew data. Removing is the best option.

# %%
# removing all rows where co2 calculation is less than 0
mauna = mauna[mauna['co2_ppm'] > 0 ]

# %%
# Checking results
mauna
# Out:
#      year  month  co2_ppm
# 0    1958      3   315.70
# 1    1958      4   317.46
# 2    1958      5   317.51
# 4    1958      7   315.86
# 5    1958      8   314.93
# ..    ...    ...      ...
# 750  2020      9   411.26
# 751  2020     10   411.23
# 752  2020     11   412.95
# 753  2020     12   413.95
# 754  2021      1   415.24
#
# [750 rows x 3 columns]

# %%
# Checking length of 'month' string where month is only 1 digit.
len(mauna['month'].map(str).loc[2])
# Out:
# 1

# %%
# Creating new dataset with datetime format date strings (for Tableau).
test_mauna = mauna
test_mauna['date'] = test_mauna['year'].map(str) + '-' + test_mauna['month'].map(str) + '-01'
test_mauna
# Out:
#      year  month  co2_ppm        date
# 0    1958      3   315.70   1958-3-01
# 1    1958      4   317.46   1958-4-01
# 2    1958      5   317.51   1958-5-01
# 4    1958      7   315.86   1958-7-01
# 5    1958      8   314.93   1958-8-01
# ..    ...    ...      ...         ...
# 750  2020      9   411.26   2020-9-01
# 751  2020     10   411.23  2020-10-01
# 752  2020     11   412.95  2020-11-01
# 753  2020     12   413.95  2020-12-01
# 754  2021      1   415.24   2021-1-01
#
# [750 rows x 4 columns]

# %%
# Create a new dataframe to merge Sydney data - Year, month, and mean temperature
syd_mean = syd_lookup.groupby(['year','month'], as_index=False)[['max_temp_adj']].mean().rename(columns={'max_temp_adj':'mean_max_temp'})
syd_mean
# Out:
#       year  month  mean_max_temp
# 0     1859      1      21.435767
# 1     1859      2      21.291939
# 2     1859      3      21.117169
# 3     1859      4      22.367634
# 4     1859      5      21.672605
# ...    ...    ...            ...
# 1935  2020      4      23.580967
# 1936  2020      5      22.408089
# 1937  2020      6      23.331481
# 1938  2020      7      23.275114
# 1939  2020      8      23.077362
#
# [1940 rows x 3 columns]

# %%
# Add datetime string format for easy merge on date
syd_mean['date'] = syd_mean['year'].map(str) + '-' + syd_mean['month'].map(str) + '-01'
syd_mean
# Out:
#       year  month  mean_max_temp       date
# 0     1859      1      21.435767  1859-1-01
# 1     1859      2      21.291939  1859-2-01
# 2     1859      3      21.117169  1859-3-01
# 3     1859      4      22.367634  1859-4-01
# 4     1859      5      21.672605  1859-5-01
# ...    ...    ...            ...        ...
# 1935  2020      4      23.580967  2020-4-01
# 1936  2020      5      22.408089  2020-5-01
# 1937  2020      6      23.331481  2020-6-01
# 1938  2020      7      23.275114  2020-7-01
# 1939  2020      8      23.077362  2020-8-01
#
# [1940 rows x 4 columns]

# %%
# Merge aggregated sydney data and prepared mauna data using the new "date" column.
combo_data = test_mauna.merge(syd_mean, how='left', on='date', suffixes=('_mau', '_syd'), copy=False, validate='1:1')
combo_data[combo_data['year_syd'].isnull()]
# Out:
#      year_mau  month_mau  co2_ppm        date  year_syd  month_syd  \
# 745      2020          9   411.26   2020-9-01       NaN        NaN
# 746      2020         10   411.23  2020-10-01       NaN        NaN
# 747      2020         11   412.95  2020-11-01       NaN        NaN
# 748      2020         12   413.95  2020-12-01       NaN        NaN
# 749      2021          1   415.24   2021-1-01       NaN        NaN
#
#      mean_max_temp
# 745            NaN
# 746            NaN
# 747            NaN
# 748            NaN
# 749            NaN

# %%
# Remove nulls from merge, check output
combo_data = combo_data[combo_data['year_syd'].notnull()]
combo_data
# Out:
#      year_mau  month_mau  co2_ppm       date  year_syd  month_syd  \
# 0        1958          3   315.70  1958-3-01    1958.0        3.0
# 1        1958          4   317.46  1958-4-01    1958.0        4.0
# 2        1958          5   317.51  1958-5-01    1958.0        5.0
# 3        1958          7   315.86  1958-7-01    1958.0        7.0
# 4        1958          8   314.93  1958-8-01    1958.0        8.0
# ..        ...        ...      ...        ...       ...        ...
# 740      2020          4   416.18  2020-4-01    2020.0        4.0
# 741      2020          5   417.16  2020-5-01    2020.0        5.0
# 742      2020          6   416.30  2020-6-01    2020.0        6.0
# 743      2020          7   414.49  2020-7-01    2020.0        7.0
# 744      2020          8   412.59  2020-8-01    2020.0        8.0
#
#      mean_max_temp
# 0        23.197814
# 1        22.377634
# 2        24.875831
# 3        22.184791
# 4        22.215319
# ..             ...
# 740      23.580967
# 741      22.408089
# 742      23.331481
# 743      23.275114
# 744      23.077362
#
# [745 rows x 7 columns]

# %%
# Export for Tableau
combo_data.to_csv('mauna_syd_combo.csv')

# %% [markdown]
# # Exploring Florida

# %%
# reading in dataset
florida = pd.read_csv('Florida.csv')

# %%
# checking output 
florida.head()
# Out:
#        STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION     DATE  \
# 0  USC00081641  CLERMONT 9 S, FL US   28.4558   -81.7234       39.6  1950-05
# 1  USC00081641  CLERMONT 9 S, FL US   28.4558   -81.7234       39.6  1950-06
# 2  USC00081641  CLERMONT 9 S, FL US   28.4558   -81.7234       39.6  1950-07
# 3  USC00081641  CLERMONT 9 S, FL US   28.4558   -81.7234       39.6  1950-08
# 4  USC00081641  CLERMONT 9 S, FL US   28.4558   -81.7234       39.6  1950-09
#
#      CDSD   CLDD  DP01  DP10  ...  EMSN   EMXP  EMXT   HDSD  HTDD   PRCP  \
# 0   510.6  234.0   8.0   5.0  ...   0.0   68.6  36.1  205.4   0.0  103.4
# 1   813.9  303.3  12.0   9.0  ...   0.0   24.6  37.2  205.4   0.0  108.7
# 2  1103.1  289.2  16.0  12.0  ...   0.0   33.5  36.1    0.0   0.0  120.0
# 3  1400.1  297.0  17.0  14.0  ...   0.0   48.3  35.6    0.0   0.0  163.0
# 4  1651.1  251.0  11.0   8.0  ...   0.0  185.2  35.0    0.0   0.0  391.6
#
#    SNOW  TAVG  TMAX  TMIN
# 0   0.0  25.9  32.9  18.9
# 1   0.0  28.4  35.3  21.6
# 2   0.0  27.7  33.6  21.7
# 3   0.0  27.9  33.8  22.1
# 4   0.0  26.7  31.7  21.7
#
# [5 rows x 29 columns]

# %%
# check for significant nulls
florida['PRCP'].isnull().sum()
# Out:
# 3

# %%
# build function to normalise weather into Precipitation & Temperature yearly averages
def normalise_weather(city):
    city['DATE'] = city['DATE'].map(str) + '-01'
    city['YEAR'] = city['DATE'].str.slice(stop=4)
    city['MONTH'] = city['DATE'].str.slice(start=5, stop=7)
    city = city[city['TMAX'].notnull()]
    # find monthly temp mean
    weather_month = city.groupby(by='MONTH', as_index=False)[['PRCP', 'TMAX']].mean()
    mean_temp = city['TMAX'].mean()
    weather_month['T_DIFF'] = weather_month['TMAX'] - mean_temp
    # find monthly precipitation mean
    mean_prcp = city['PRCP'].mean()
    weather_month['P_DIFF'] = weather_month['PRCP'] - mean_prcp
    # merge into new dataset
    combo = city.merge(weather_month, how='left', on='MONTH', validate='m:1', suffixes=('_city', '_month'))
    combo['TEMP_ADJ'] = combo['TMAX_city'] - combo['T_DIFF']
    combo['PRCP_ADJ'] = combo['PRCP_city'] - combo['P_DIFF']
    # create output Dataframe
    avg = combo.groupby(by='YEAR', as_index=False)[['PRCP_ADJ', 'TEMP_ADJ']].mean()
    return avg

# %%
# execute function on florida dataset
florida_adjusted = normalise_weather(florida)

# %%
# check output
florida_adjusted
# Out:
#     YEAR    PRCP_ADJ   TEMP_ADJ
# 0   1950  128.537724  28.462107
# 1   1951  107.970840  28.986726
# 2   1952   87.791250  28.634861
# 3   1953  140.491250  28.509861
# 4   1954   74.316250  28.359861
# ..   ...         ...        ...
# 66  2016  115.774583  29.518194
# 67  2017  111.602011  30.113254
# 68  2018  128.082916  29.359861
# 69  2019  117.104129  29.840068
# 70  2020  109.979754  29.709485
#
# [71 rows x 3 columns]

# %%
# export for Tableau
florida_adjusted.to_csv('Florida_adj.csv')
